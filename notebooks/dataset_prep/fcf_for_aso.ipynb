# %% [markdown]
# # Download fcf data for aso rasters
# This notebook contains functions to download and extract fractional forest cover (fcf) data for ASO rasters

# %%
import sys
import os
from os.path import basename, exists, expanduser, join
import shutil
import shapely
import rioxarray as rxr
import xarray as xr
import time
import gzip
from urllib.request import urlretrieve
import matplotlib.pyplot as plt
import glob
import rasterio as rio

# %% [markdown]
# ## Download fcf data

# %%
def url_download(url, out_fp, overwrite = False):
    # check if file already exists
    if not exists(out_fp) or overwrite == True:
            urlretrieve(url, out_fp)
    # if already exists. skip download.
    else:
        print('file already exists, skipping')

# %%
def download_fcf(out_fp):
    # this is the url from Lievens et al. 2021 paper
    fcf_url = 'https://zenodo.org/record/3939050/files/PROBAV_LC100_global_v3.0.1_2019-nrt_Tree-CoverFraction-layer_EPSG-4326.tif'
    # download just forest cover fraction to out file
    url_download(fcf_url, out_fp)

# %%
fcf_path ='../data/tmp/fcf_global.tif'
download_fcf(fcf_path)

# %% [markdown]
# ## extract fcf data for aso rasters

# %%
def fcf_for_aso(aso_raster_fn, fcf_path):
    aso_raster = rxr.open_rasterio(aso_raster_fn).squeeze()
    aso_raster = aso_raster.where(aso_raster>=0, drop=True)
    aso_raster = aso_raster.interpolate_na(dim='x')
    
    # open as dataArray and return
    fcf = rxr.open_rasterio(fcf_path)

    # clip first to avoid super long reproject processes
    fcf = fcf.rio.clip_box(*aso_raster.rio.transform_bounds("EPSG:4326"))
    # reproject FCF to match dataset
    fcf = fcf.rio.reproject_match(aso_raster, resampling=rio.enums.Resampling.bilinear)
    # remove band dimension as it only has one band
    fcf = fcf.squeeze('band')
    # if max is greater than 1 set to 0-1
    if fcf.max() >= 1:
        fcf = fcf / 100
    
    assert fcf.max() <= 1, "Forest cover fraction must be bounded 0-1"
    assert fcf.min() >= 0, "Forest cover fraction must be bounded 0-1"
    
    fcf.to_netcdf(f'../data/fcf/fcf_for_{aso_raster_fn.split("/")[-1][:-4]}.nc')

    #return fcf, aso_raster

# %%
# fn = '/home/jovyan/deep-snow/data/ASO/ASO_50m_SD_cleaned/utm10n/ASO_50M_SD_SacramentoMcCloud_20230209_clean.tif'

# %%
# fcf_da, aso = fcf_for_aso(fn)

# %%
# f, ax = plt.subplots(1, 2, figsize = (10, 10))
# ax[0].imshow(fcf_da)
# ax[0].set_aspect('equal')
# ax[1].imshow(aso, vmin=0, vmax=2, cmap = "Blues")
# ax[1].set_aspect('equal')
# plt.tight_layout()

# %%
def fcf_for_aso_all(dir_path, fcf_path):
    raster_paths = glob.glob(f'{dir_path}/*/ASO_50M_SD*.tif')
    for i, path in enumerate(raster_paths):
        print(f'----\nworking on {path.split("/")[-1]}, {i+1}/{len(raster_paths)}\n----')

        fcf_for_aso(path, fcf_path)

# %%
dir_path = '/home/jovyan/deep-snow/data/ASO/ASO_50m_SD_cleaned'
fcf_for_aso_all(dir_path, fcf_path)
# Out:
# ----
# working on ASO_50M_SD_BlueRiver_20230529_clean.tif, 1/252
# ----
# ----
# working on ASO_50M_SD_Animas_20210419_clean.tif, 2/252
# ----
# ----
# working on ASO_50M_SD_EastRiver_20230523_clean.tif, 3/252
# ----
# ----
# working on ASO_50M_SD_EastRiver_20220518_clean.tif, 4/252
# ----
# ----
# working on ASO_50M_SD_SouthPlatte_20230416_clean.tif, 5/252
# ----
# ----
# working on ASO_50M_SD_USCOCM_20190407_clean.tif, 6/252
# ----
# ----
# working on ASO_50M_SD_TaylorAndLottis_20230523_clean.tif, 7/252
# ----
# ----
# working on ASO_50M_SD_USCOGE_20180331_clean.tif, 8/252
# ----
# ----
# working on ASO_50M_SD_BlueRiver_20190624_clean.tif, 9/252
# ----
# ----
# working on ASO_50M_SD_BlueRiver_20230416_clean.tif, 10/252
# ----
# ----
# working on ASO_50M_SD_WindyGap_20230416_clean.tif, 11/252
# ----
# ----
# working on ASO_50M_SD_RoaringFork_20230528_clean.tif, 12/252
# ----
# ----
# working on ASO_50M_SD_USCOBR_20190624_clean.tif, 13/252
# ----
# ----
# working on ASO_50M_SD_USCOFR_20210319_clean.tif, 14/252
# ----
# ----
# working on ASO_50M_SD_Blue_20220526_clean.tif, 15/252
# ----
# ----
# working on ASO_50M_SD_Gunnison_20220421_clean.tif, 16/252
# ----
# ----
# working on ASO_50M_SD_SouthPlatte_20230526_clean.tif, 17/252
# ----
# ----
# working on ASO_50M_SD_WindyGap_20230527_clean.tif, 18/252
# ----
# ----
# working on ASO_50M_SD_Poudre_20230522_clean.tif, 19/252
# ----
# ----
# working on ASO_50M_SD_EastRiver_20230401_clean.tif, 20/252
# ----
# ----
# working on ASO_50M_SD_BlueRiver_20210418_clean.tif, 21/252
# ----
# ----
# working on ASO_50M_SD_WindyGap_20220418_clean.tif, 22/252
# ----
# ----
# working on ASO_50M_SD_ClearCreek_20230509_clean.tif, 23/252
# ----
# ----
# working on ASO_50M_SD_GunnisonTaylor_20220421_clean.tif, 24/252
# ----
# ----
# working on ASO_50M_SD_USCOCB_20180330_clean.tif, 25/252
# ----
# ----
# working on ASO_50M_SD_BigThompsonLittleThompson_20230521_clean.tif, 26/252
# ----
# ----
# working on ASO_50M_SD_USCOGE_20190610_clean.tif, 27/252
# ----
# ----
# working on ASO_50M_SD_Blue_20220419_clean.tif, 28/252
# ----
# ----
# working on ASO_50M_SD_GunnisonTaylor_20220525_clean.tif, 29/252
# ----
# ----
# working on ASO_50M_SD_USCOCM_20190610_clean.tif, 30/252
# ----
# ----
# working on ASO_50M_SD_Conejos_20220510_clean.tif, 31/252
# ----
# ----
# working on ASO_50M_SD_USCOGT_20190609_clean.tif, 32/252
# ----
# ----
# working on ASO_50M_SD_Conejos_20220415_clean.tif, 33/252
# ----
# ----
# working on ASO_50M_SD_BoulderCreek_20230509_clean.tif, 34/252
# ----
# ----
# working on ASO_50M_SD_WindyGap_20220526_clean.tif, 35/252
# ----
# ----
# working on ASO_50M_SD_Conejos_20230505_clean.tif, 36/252
# ----
# ----
# working on ASO_50M_SD_USCOCJ_20160403_clean.tif, 37/252
# ----
# ----
# working on ASO_50M_SD_USCOFR_20200211_clean.tif, 38/252
# ----
# ----
# working on ASO_50M_SD_RoaringFork_20230411_clean.tif, 39/252
# ----
# ----
# working on ASO_50M_SD_BlueRiver_20210524_clean.tif, 40/252
# ----
# ----
# working on ASO_50M_SD_USCORG_20160403_clean.tif, 41/252
# ----
# ----
# working on ASO_50M_SD_USCOGE_20180524_clean.tif, 42/252
# ----
# ----
# working on ASO_50M_SD_USCOGT_20180330_clean.tif, 43/252
# ----
# ----
# working on ASO_50M_SD_Taylor_20230401_clean.tif, 44/252
# ----
# ----
# working on ASO_50M_SD_TenMileCk_20190613_clean.tif, 45/252
# ----
# ----
# working on ASO_50M_SD_USCOGE_20190407_clean.tif, 46/252
# ----
# ----
# working on ASO_50M_SD_Conejos_20210420_clean.tif, 47/252
# ----
# ----
# working on ASO_50M_SD_USCOBR_20190419_clean.tif, 48/252
# ----
# ----
# working on ASO_50M_SD_StVrainLefthand_20230521_clean.tif, 49/252
# ----
# ----
# working on ASO_50M_SD_Conejos_20210516_clean.tif, 50/252
# ----
# ----
# working on ASO_50M_SD_BlueRiver_20190419_clean.tif, 51/252
# ----
# ----
# working on ASO_50M_SD_USCOCP_20210319_clean.tif, 52/252
# ----
# ----
# working on ASO_50M_SD_USCOGT_20190408_clean.tif, 53/252
# ----
# ----
# working on ASO_50M_SD_UpperOwensBasin_20230702_clean.tif, 54/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20230124_clean.tif, 55/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20170815_clean.tif, 56/252
# ----
# ----
# working on ASO_50M_SD_Carson_20220513_clean.tif, 57/252
# ----
# ----
# working on ASO_50M_SD_Merced_20200521_clean.tif, 58/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160401_clean.tif, 59/252
# ----
# ----
# working on ASO_50M_SD_Merced_20230303_clean.tif, 60/252
# ----
# ----
# working on ASO_50M_SD_Merced_20230131_clean.tif, 61/252
# ----
# ----
# working on ASO_50M_SD_Kings_20230122_clean.tif, 62/252
# ----
# ----
# working on ASO_50M_SD_USCARC_20160412_clean.tif, 63/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20170717_clean.tif, 64/252
# ----
# ----
# working on ASO_50M_SD_Merced_20230515_clean.tif, 65/252
# ----
# ----
# working on ASO_50M_SD_Merced_20220301_clean.tif, 66/252
# ----
# ----
# working on ASO_50M_SD_UpperOwensBasin_20230527_clean.tif, 67/252
# ----
# ----
# working on ASO_50M_SD_USCAMB_20190716_clean.tif, 68/252
# ----
# ----
# working on ASO_50M_SD_USIDBS_20210315_clean.tif, 69/252
# ----
# ----
# working on ASO_50M_SD_Merced_20220412_clean.tif, 70/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20160621_clean.tif, 71/252
# ----
# ----
# working on ASO_50M_SD_USCAJW_20190605_clean.tif, 72/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20160614_clean.tif, 73/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160326_clean.tif, 74/252
# ----
# ----
# working on ASO_50M_SD_USCATE_20190705_clean.tif, 75/252
# ----
# ----
# working on ASO_50M_SD_Mono_20230702_clean.tif, 76/252
# ----
# ----
# working on ASO_50M_SD_Carson_20230510_clean.tif, 77/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190427_clean.tif, 78/252
# ----
# ----
# working on ASO_50M_SD_Kern_20230429_clean.tif, 79/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20160509_clean.tif, 80/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20230423_clean.tif, 81/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190428_clean.tif, 82/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20220228_clean.tif, 83/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20190609_clean.tif, 84/252
# ----
# ----
# working on ASO_50M_SD_Kern_20230204_clean.tif, 85/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20160607_clean.tif, 86/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20200608_clean.tif, 87/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20230316_clean.tif, 88/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20220417_clean.tif, 89/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20180601_clean.tif, 90/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20180304_clean.tif, 91/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20220204_clean.tif, 92/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20190325_clean.tif, 93/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20220405_clean.tif, 94/252
# ----
# ----
# working on ASO_50M_SD_Merced_20210526_clean.tif, 95/252
# ----
# ----
# working on ASO_50M_SD_Kings_20230528_clean.tif, 96/252
# ----
# ----
# working on ASO_50M_SD_Merced_20230608_clean.tif, 97/252
# ----
# ----
# working on ASO_50M_SD_USIDDC_20200219_clean.tif, 98/252
# ----
# ----
# working on ASO_50M_SD_USCAKW_20190324_clean.tif, 99/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190316_clean.tif, 100/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20190614_clean.tif, 101/252
# ----
# ----
# working on ASO_50M_SD_USCAMB_20190703_clean.tif, 102/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20170718_clean.tif, 103/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20170816_clean.tif, 104/252
# ----
# ----
# working on ASO_50M_SD_Mono_20230527_clean.tif, 105/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20230307_clean.tif, 106/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20170719_clean.tif, 107/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20220517_clean.tif, 108/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20230121_clean.tif, 109/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20210331_clean.tif, 110/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160708_clean.tif, 111/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20210423_clean.tif, 112/252
# ----
# ----
# working on ASO_50M_SD_USCAJW_20180602_clean.tif, 113/252
# ----
# ----
# working on ASO_50M_SD_Kings_20230421_clean.tif, 114/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20230414_clean.tif, 115/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20220429_clean.tif, 116/252
# ----
# ----
# working on ASO_50M_SD_USCARC_20170717_clean.tif, 117/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20220316_clean.tif, 118/252
# ----
# ----
# working on ASO_50M_SD_Kings_20230630_clean.tif, 119/252
# ----
# ----
# working on ASO_50M_SD_USIDMC_20200209_clean.tif, 120/252
# ----
# ----
# working on ASO_50M_SD_Kern_20230326_clean.tif, 121/252
# ----
# ----
# working on ASO_50M_SD_USCAMB_20190604_clean.tif, 122/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20190713_clean.tif, 123/252
# ----
# ----
# working on ASO_50M_SD_Mono_20230615_clean.tif, 124/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20210226_clean.tif, 125/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20230523_clean.tif, 126/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20180422_clean.tif, 127/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20180423_clean.tif, 128/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190611_clean.tif, 129/252
# ----
# ----
# working on ASO_50M_SD_Carson_20230331_clean.tif, 130/252
# ----
# ----
# working on ASO_50M_SD_Merced_20220428_clean.tif, 131/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20190502_clean.tif, 132/252
# ----
# ----
# working on ASO_50M_SD_USCALV_20170717_clean.tif, 133/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20230127_clean.tif, 134/252
# ----
# ----
# working on ASO_50M_SD_Kern_20230603_clean.tif, 135/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20190309_clean.tif, 136/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190608_clean.tif, 137/252
# ----
# ----
# working on ASO_50M_SD_Merced_20230326_clean.tif, 138/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20220327_clean.tif, 139/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20190715_clean.tif, 140/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20190714_clean.tif, 141/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20190317_clean.tif, 142/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20220518_clean.tif, 143/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20210224_clean.tif, 144/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20230626_clean.tif, 145/252
# ----
# ----
# working on ASO_50M_SD_Merced_20200604_clean.tif, 146/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160416_clean.tif, 147/252
# ----
# ----
# working on ASO_50M_SD_Kings_20230316_clean.tif, 148/252
# ----
# ----
# working on ASO_50M_SD_Carson_20220406_clean.tif, 149/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20190704_clean.tif, 150/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20190611_clean.tif, 151/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20170129_clean.tif, 152/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160509_clean.tif, 153/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20230427_clean.tif, 154/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20180423_clean.tif, 155/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20200507_clean.tif, 156/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20210429_clean.tif, 157/252
# ----
# ----
# working on ASO_50M_SD_UpperOwensBasin_20230615_clean.tif, 158/252
# ----
# ----
# working on ASO_50M_SD_USCASF_20190704_clean.tif, 159/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20230405_clean.tif, 160/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160426_clean.tif, 161/252
# ----
# ----
# working on ASO_50M_SD_USCAJW_20190315_clean.tif, 162/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20230623_clean.tif, 163/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20190703_clean.tif, 164/252
# ----
# ----
# working on ASO_50M_SD_Merced_20200413_clean.tif, 165/252
# ----
# ----
# working on ASO_50M_SD_USIDMC_20210315_clean.tif, 166/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160607_clean.tif, 167/252
# ----
# ----
# working on ASO_50M_SD_USCAKW_20190317_clean.tif, 168/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20230601_clean.tif, 169/252
# ----
# ----
# working on ASO_50M_SD_USCATE_20190613_clean.tif, 170/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20210504_clean.tif, 171/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190326_clean.tif, 172/252
# ----
# ----
# working on ASO_50M_SD_USCAMB_20180425_clean.tif, 173/252
# ----
# ----
# working on ASO_50M_SD_Kings_20230331_clean.tif, 174/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20210503_clean.tif, 175/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20180528_clean.tif, 176/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20190418_clean.tif, 177/252
# ----
# ----
# working on ASO_50M_SD_Merced_20200507_clean.tif, 178/252
# ----
# ----
# working on ASO_50M_SD_USCAJW_20180423_clean.tif, 179/252
# ----
# ----
# working on ASO_50M_SD_Merced_20210429_clean.tif, 180/252
# ----
# ----
# working on ASO_50M_SD_Carson_20220311_clean.tif, 181/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20230302_clean.tif, 182/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20180601_clean.tif, 183/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20230317_clean.tif, 184/252
# ----
# ----
# working on ASO_50M_SD_USCATE_20190503_clean.tif, 185/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20220206_clean.tif, 186/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20200413_clean.tif, 187/252
# ----
# ----
# working on ASO_50M_SD_USCAKN_20190417_clean.tif, 188/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20230602_clean.tif, 189/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20180601_clean.tif, 190/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160407_clean.tif, 191/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20170128_clean.tif, 192/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20160626_clean.tif, 193/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20200523_clean.tif, 194/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20190501_clean.tif, 195/252
# ----
# ----
# working on ASO_50M_SD_USCAMB_20190329_clean.tif, 196/252
# ----
# ----
# working on ASO_50M_SD_Merced_20220513_clean.tif, 197/252
# ----
# ----
# working on ASO_50M_SD_Tuolumne_20220429_clean.tif, 198/252
# ----
# ----
# working on ASO_50M_SD_USCALB_20190501_clean.tif, 199/252
# ----
# ----
# working on ASO_50M_SD_USCAKC_20180426_clean.tif, 200/252
# ----
# ----
# working on ASO_50M_SD_USCATE_20190324_clean.tif, 201/252
# ----
# ----
# working on ASO_50M_SD_USCATE_20190417_clean.tif, 202/252
# ----
# ----
# working on ASO_50M_SD_Kaweah_20220308_clean.tif, 203/252
# ----
# ----
# working on ASO_50M_SD_Carson_20230607_clean.tif, 204/252
# ----
# ----
# working on ASO_50M_SD_USIDBS_20200218_clean.tif, 205/252
# ----
# ----
# working on ASO_50M_SD_USCAKW_20190421_clean.tif, 206/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20170727_clean.tif, 207/252
# ----
# ----
# working on ASO_50M_SD_SanJoaquin_20220430_clean.tif, 208/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20180422_clean.tif, 209/252
# ----
# ----
# working on ASO_50M_SD_USCATB_20160527_clean.tif, 210/252
# ----
# ----
# working on ASO_50M_SD_USCAKN_20180426_clean.tif, 211/252
# ----
# ----
# working on ASO_50M_SD_USCASJ_20170815_clean.tif, 212/252
# ----
# ----
# working on ASO_50M_SD_SacramentoMcCloud_20230209_clean.tif, 213/252
# ----
# ----
# working on ASO_50M_SD_SacramentoMcCloud_20230515_clean.tif, 214/252
# ----
# ----
# working on ASO_50M_SD_Feather_20230206_clean.tif, 215/252
# ----
# ----
# working on ASO_50M_SD_Sprague_20230514_clean.tif, 216/252
# ----
# ----
# working on ASO_50M_SD_Yuba_20230426_clean.tif, 217/252
# ----
# ----
# working on ASO_50M_SD_LowerPit_20230425_clean.tif, 218/252
# ----
# ----
# working on ASO_50M_SD_LowerPit_20230511_clean.tif, 219/252
# ----
# ----
# working on ASO_50M_SD_Feather_20230409_clean.tif, 220/252
# ----
# ----
# working on ASO_50M_SD_Truckee_20230608_clean.tif, 221/252
# ----
# ----
# working on ASO_50M_SD_American_20230131_clean.tif, 222/252
# ----
# ----
# working on ASO_50M_SD_LowerPit_20230212_clean.tif, 223/252
# ----
# ----
# working on ASO_50M_SD_Truckee_20230511_clean.tif, 224/252
# ----
# ----
# working on ASO_50M_SD_Truckee_20220310_clean.tif, 225/252
# ----
# ----
# working on ASO_50M_SD_Feather_20220429_clean.tif, 226/252
# ----
# ----
# working on ASO_50M_SD_SacramentoMcCloud_20230424_clean.tif, 227/252
# ----
# ----
# working on ASO_50M_SD_USWAOL_20160208_clean.tif, 228/252
# ----
# ----
# working on ASO_50M_SD_Yuba_20230531_clean.tif, 229/252
# ----
# ----
# working on ASO_50M_SD_Truckee_20230409_clean.tif, 230/252
# ----
# ----
# working on ASO_50M_SD_Feather_20230428_clean.tif, 231/252
# ----
# ----
# working on ASO_50M_SD_American_20230413_clean.tif, 232/252
# ----
# ----
# working on ASO_50M_SD_American_20230428_clean.tif, 233/252
# ----
# ----
# working on ASO_50M_SD_Feather_20230618_clean.tif, 234/252
# ----
# ----
# working on ASO_50M_SD_Feather_20220310_clean.tif, 235/252
# ----
# ----
# working on ASO_50M_SD_Truckee_20220408_clean.tif, 236/252
# ----
# ----
# working on ASO_50M_SD_Feather_20220331_clean.tif, 237/252
# ----
# ----
# working on ASO_50M_SD_Truckee_20220514_clean.tif, 238/252
# ----
# ----
# working on ASO_50M_SD_Yuba_20230405_clean.tif, 239/252
# ----
# ----
# working on ASO_50M_SD_Yuba_20230625_clean.tif, 240/252
# ----
# ----
# working on ASO_50M_SD_USWAOL_20160329_clean.tif, 241/252
# ----
# ----
# working on ASO_50M_SD_American_20230602_clean.tif, 242/252
# ----
# ----
# working on ASO_50M_SD_Yuba_20230128_clean.tif, 243/252
# ----
# ----
# working on ASO_50M_SD_GreenRiver_20220611_clean.tif, 244/252
# ----
# ----
# working on ASO_50M_SD_Dolores_20230406_clean.tif, 245/252
# ----
# ----
# working on ASO_50M_SD_USUTLC_20210318_clean.tif, 246/252
# ----
# ----
# working on ASO_50M_SD_Dolores_20220415_clean.tif, 247/252
# ----
# ----
# working on ASO_50M_SD_Dolores_20210514_clean.tif, 248/252
# ----
# ----
# working on ASO_50M_SD_WindRiver_20220611_clean.tif, 249/252
# ----
# ----
# working on ASO_50M_SD_Dolores_20230525_clean.tif, 250/252
# ----
# ----
# working on ASO_50M_SD_Dolores_20220510_clean.tif, 251/252
# ----
# ----
# working on ASO_50M_SD_Dolores_20210420_clean.tif, 252/252
# ----

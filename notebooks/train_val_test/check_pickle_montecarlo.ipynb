# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open(f'../../loss/ResDepth_montecarlo_v0.pkl', 'rb') as f:
        experiment_data = pickle.load(f)

# %%
# define input channels for model
all_input_channels = [
    'snowon_vv',
    'snowon_vh',
    'snowoff_vv',
    'snowoff_vh',
    'snowon_cr',
    'snowoff_cr',
    'delta_cr',
    'blue',
    'green',
    'red',
    'nir',
    'swir1',
    'swir2',
    'ndvi',
    'ndsi',
    'ndwi',
    'fcf',
    'elevation',
    'slope',
    'aspect',
    'curvature',
    'tri',
    'tpi',
    'latitude',
    'longitude',
    'dowy']

# %%
val_channel_performance = {}
all_values = {}
for channel in all_input_channels:
    val_loss_w_channel = []
    val_loss_wo_channel = []
    for trial in experiment_data.keys():
        if channel in experiment_data[trial][0]:
            val_loss_w_channel.append(experiment_data[trial][1])
        else:
            val_loss_wo_channel.append(experiment_data[trial][1])
    val_loss_diff = np.mean(val_loss_wo_channel) - np.mean(val_loss_w_channel)
    val_channel_performance[channel] = val_loss_diff
    all_values[channel] = [val_loss_w_channel, val_loss_wo_channel]

df = pd.DataFrame({
    'channels': val_channel_performance.keys(),
    'val_loss_diff': val_channel_performance.values()
})

df_summary = df.sort_values('val_loss_diff', ascending=False)

# %%
# Find the maximum length of the lists
max_len = max(max(len(lst) for lst in metrics) for metrics in all_values.values())

# Convert dictionary to DataFrame
rows = []
for channel, metrics in all_values.items():
    for i in range(max_len):
        row = [channel]
        for metric in metrics:
            if i < len(metric):
                row.append(metric[i])
            else:
                row.append(np.nan)
        rows.append(row)

df = pd.DataFrame(rows, columns=['channel', 'val_mse_w', 'val_mse_wo'])

# %%
from scipy.stats import mannwhitneyu
results = []

# Perform Mann–Whitney U tests for each channel
for channel in df['channel'].unique():
    channel_data = df[df['channel'] == channel]
    channel_obs = channel_data.val_mse_w.count()
    metric_1 = channel_data['val_mse_w'].dropna()
    metric_2 = channel_data['val_mse_wo'].dropna()
    
    # Mann–Whitney U test for metrics 1 and 2
    stat_val, p_val = mannwhitneyu(metric_1, metric_2)
    
    # Append results to the list
    results.append([channel, p_val, channel_obs])

# Convert results to DataFrame
results_df = pd.DataFrame(results, columns=['channel', 'p_val', 'n'])
results_df
# Out:
#        channel     p_val   n
# 0    snowon_vv  0.053147  38
# 1    snowon_vh  0.628391  32
# 2   snowoff_vv  0.916894  33
# 3   snowoff_vh  0.307376  32
# 4    snowon_cr  0.971047  33
# 5   snowoff_cr  0.479498  30
# 6     delta_cr  0.286379  34
# 7         blue  0.004014  28
# 8        green  0.002155  31
# 9          red  0.052800  28
# 10         nir  0.007919  29
# 11       swir1  0.392483  34
# 12       swir2  0.614060  25
# 13        ndvi  0.776622  27
# 14        ndsi  0.002996  21
# 15        ndwi  0.662468  28
# 16         fcf  0.245901  34
# 17   elevation  0.043357  21
# 18       slope  0.626911  22
# 19      aspect  0.168026  32
# 20   curvature  0.232636  27
# 21         tri  0.603883  26
# 22         tpi  0.014647  27
# 23    latitude  0.000493  32
# 24   longitude  0.935248  21
# 25        dowy  0.308365  25

# %%
sns.set_theme()

# Create subplots
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 5))

# Bottom plot: Performance metrics 3 and 4
sns.boxplot(x='channel', y='value', hue='metric', data=pd.melt(df, id_vars=['channel'], value_vars=['val_mse_w', 'val_mse_wo'], var_name='metric'), ax=ax)
ax.set_title('validation performance with and without channel')
ax.set_ylabel('MSE')
ax.set_xlabel('')
ax.tick_params(axis='x', rotation=90)
ax.set_ylim(None, None)

# Adjust layout
plt.tight_layout()

# %%
# Set the position of the bars on the x-axis
bar_width = 0.35
r1 = np.arange(len(df_summary['channels']))

# Create the plot
fig, ax = plt.subplots(figsize=(10, 3))
ax.bar(r1, df_summary['val_loss_diff'], color='orange', width=bar_width, edgecolor='grey', label='change in validation MSE')
# Add labels
ax.set_xlabel('channels')
ax.set_xticks([r for r in range(len(df_summary['channels']))])
ax.set_xticklabels(df_summary['channels'], rotation=90)
ax.set_ylabel('change in MSE loss', fontweight='bold')
ax.set_title('mean change in validation MSE when channels are included')
# Out:
# Text(0.5, 1.0, 'mean change in validation MSE when channels are included')

# %%
experiment_data
# Out:
# {1: [['latitude', 'swir1', 'tri', 'fcf', 'snowoff_vh'], 0.000991828343103407],
#  2: [['fcf', 'snowoff_cr', 'nir', 'snowon_vv', 'delta_cr'],
#   0.0007330565008487611],
#  3: [['longitude', 'swir2', 'tpi', 'latitude', 'snowoff_cr'],
#   0.0014202314978319919],
#  4: [['snowon_cr', 'latitude', 'tri', 'snowon_vv', 'slope'],
#   0.0016568277023907285],
#  5: [['nir', 'fcf', 'delta_cr', 'ndwi', 'dowy'], 0.0008479191574224387],
#  6: [['elevation', 'tpi', 'blue', 'slope', 'snowoff_vh'],
#   0.000596755669448612],
#  7: [['ndsi', 'aspect', 'snowon_vv', 'snowoff_vv', 'snowon_vh'],
#   0.0007644925924523704],
#  8: [['green', 'dowy', 'nir', 'snowoff_vh', 'ndwi'], 0.0008452602135093912],
#  9: [['tri', 'ndwi', 'elevation', 'snowon_cr', 'snowoff_vh'],
#   0.000953883179136028],
#  10: [['green', 'aspect', 'slope', 'dowy', 'blue'], 0.0007248822153087531],
#  11: [['ndvi', 'snowoff_vv', 'snowoff_vh', 'dowy', 'longitude'],
#   0.0010103217191499425],
#  12: [['snowoff_cr', 'green', 'slope', 'swir1', 'tpi'], 0.0007038467415441119],
#  13: [['ndwi', 'snowoff_vh', 'longitude', 'ndsi', 'nir'],
#   0.0006048865916454815],
#  14: [['red', 'tpi', 'aspect', 'snowon_vv', 'curvature'],
#   0.0008219423734772136],
#  15: [['aspect', 'delta_cr', 'snowon_cr', 'swir1', 'swir2'],
#   0.0009362054429402633],
#  16: [['ndvi', 'blue', 'aspect', 'snowoff_vv', 'snowoff_vh'],
#   0.0011096404641648405],
#  17: [['nir', 'green', 'blue', 'latitude', 'snowon_vv'],
#   0.0007781640092616726],
#  18: [['tri', 'delta_cr', 'elevation', 'snowon_cr', 'blue'],
#   0.0005259265431050153],
#  19: [['latitude', 'ndvi', 'swir1', 'snowon_vv', 'red'],
#   0.0009378872746310662],
#  20: [['snowoff_vv', 'ndsi', 'longitude', 'elevation', 'swir1'],
#   0.000747584056625783],
#  21: [['dowy', 'snowoff_vh', 'latitude', 'blue', 'snowon_vh'],
#   0.00070248922384053],
#  22: [['curvature', 'swir2', 'red', 'elevation', 'swir1'],
#   0.00048514841387259366],
#  23: [['longitude', 'snowoff_vv', 'swir1', 'ndvi', 'swir2'],
#   0.000981794124982116],
#  24: [['snowoff_vh', 'latitude', 'fcf', 'ndwi', 'dowy'],
#   0.0007668926245969487],
#  25: [['nir', 'delta_cr', 'blue', 'elevation', 'curvature'],
#   0.0005111932823638199],
#  26: [['nir', 'elevation', 'fcf', 'swir2', 'aspect'], 0.0006443033389587072],
#  27: [['snowon_cr', 'snowon_vh', 'ndvi', 'delta_cr', 'blue'],
#   0.0008414756657657563],
#  28: [['slope', 'snowon_cr', 'aspect', 'swir1', 'latitude'],
#   0.0013393173339864006],
#  29: [['snowon_cr', 'ndwi', 'snowon_vv', 'dowy', 'swir2'],
#   0.0009014169036163366],
#  30: [['snowoff_vh', 'snowon_vh', 'snowon_vv', 'tpi', 'fcf'],
#   0.0014824943227722542],
#  31: [['snowon_vv', 'elevation', 'swir2', 'snowoff_cr', 'dowy'],
#   0.0011584104599933198],
#  32: [['swir2', 'swir1', 'longitude', 'ndvi', 'ndwi'], 0.0007305594949684746],
#  33: [['ndvi', 'curvature', 'ndwi', 'snowoff_vv', 'green'],
#   0.0008292266038552043],
#  34: [['nir', 'fcf', 'longitude', 'snowon_vv', 'snowon_vh'],
#   0.0009570204374540481],
#  35: [['ndwi', 'snowoff_vv', 'swir1', 'slope', 'snowon_cr'],
#   0.0009731821319292067],
#  36: [['snowon_cr', 'tpi', 'ndvi', 'ndwi', 'snowoff_cr'],
#   0.000979274255769269],
#  37: [['snowoff_vh', 'snowon_vv', 'delta_cr', 'snowon_cr', 'curvature'],
#   0.0014254428242566064],
#  38: [['nir', 'fcf', 'snowoff_cr', 'snowoff_vv', 'ndwi'],
#   0.0006856944651190133],
#  39: [['snowon_cr', 'snowon_vv', 'fcf', 'aspect', 'swir2'],
#   0.0010698566693463363],
#  40: [['slope', 'latitude', 'swir2', 'aspect', 'snowoff_vh'],
#   0.0015353214330389164],
#  41: [['snowon_vv', 'snowon_cr', 'nir', 'snowoff_cr', 'longitude'],
#   0.0006459036542310059],
#  42: [['snowon_vv', 'tpi', 'aspect', 'swir1', 'snowoff_vv'],
#   0.001050283265158214],
#  43: [['ndvi', 'ndwi', 'snowoff_vv', 'blue', 'delta_cr'],
#   0.0007204760063359572],
#  44: [['snowon_vh', 'tpi', 'ndsi', 'blue', 'elevation'],
#   0.0005605598717011162],
#  45: [['fcf', 'ndsi', 'ndwi', 'ndvi', 'snowoff_vv'], 0.0006713754646625603],
#  46: [['ndwi', 'ndvi', 'green', 'snowon_cr', 'dowy'], 0.0008461851136871701],
#  47: [['curvature', 'longitude', 'ndwi', 'blue', 'nir'],
#   0.0007767765746393707],
#  48: [['swir1', 'red', 'snowoff_cr', 'fcf', 'aspect'], 0.0006126456028141547],
#  49: [['snowon_vv', 'fcf', 'curvature', 'snowon_cr', 'ndvi'],
#   0.0007945481302158441],
#  50: [['ndsi', 'ndvi', 'green', 'delta_cr', 'aspect'], 0.000889381192791916],
#  51: [['red', 'green', 'fcf', 'swir1', 'swir2'], 0.0008946994587404333],
#  52: [['latitude', 'snowon_cr', 'snowoff_vv', 'red', 'delta_cr'],
#   0.0008437206524831709],
#  53: [['aspect', 'snowon_vv', 'snowon_vh', 'elevation', 'longitude'],
#   0.0013215044518801733],
#  54: [['green', 'aspect', 'delta_cr', 'snowon_vv', 'fcf'],
#   0.0006379584747264744],
#  55: [['tri', 'snowon_cr', 'aspect', 'fcf', 'ndsi'], 0.0005463162938212918],
#  56: [['delta_cr', 'snowoff_cr', 'nir', 'dowy', 'longitude'],
#   0.0006813697318648337],
#  57: [['nir', 'ndvi', 'snowoff_cr', 'aspect', 'dowy'], 0.0009794282486836892],
#  58: [['slope', 'blue', 'snowon_cr', 'longitude', 'green'],
#   0.0006953225558845588],
#  59: [['tpi', 'swir1', 'ndvi', 'snowon_vv', 'tri'], 0.0010310327852494083],
#  60: [['snowon_vv', 'red', 'tri', 'snowoff_vh', 'slope'],
#   0.0006617750582336157],
#  61: [['green', 'blue', 'snowoff_vh', 'snowoff_cr', 'red'],
#   0.0007007772469478368],
#  62: [['fcf', 'longitude', 'snowoff_vh', 'latitude', 'tri'],
#   0.0013980675057609915],
#  63: [['dowy', 'green', 'red', 'tri', 'ndvi'], 0.0007761783945170464],
#  64: [['ndwi', 'blue', 'snowoff_cr', 'ndvi', 'tpi'], 0.0010576954045973253],
#  65: [['green', 'dowy', 'fcf', 'snowoff_vv', 'ndsi'], 0.0007247069522691163],
#  66: [['slope', 'fcf', 'dowy', 'snowoff_cr', 'latitude'],
#   0.001459842922486132],
#  67: [['swir1', 'green', 'elevation', 'snowoff_vv', 'snowon_vh'],
#   0.00048552953444414015],
#  68: [['latitude', 'delta_cr', 'snowon_vv', 'longitude', 'snowoff_vv'],
#   0.001110161233555118],
#  69: [['snowoff_cr', 'slope', 'snowon_cr', 'snowon_vv', 'aspect'],
#   0.0013864775119145634],
#  70: [['latitude', 'elevation', 'tpi', 'snowon_vh', 'fcf'],
#   0.0015968383995641489],
#  71: [['snowon_cr', 'nir', 'ndwi', 'snowoff_vh', 'elevation'],
#   0.0006119670438238245],
#  72: [['tpi', 'ndsi', 'snowon_vv', 'snowoff_vv', 'snowon_vh'],
#   0.0007744806730443088],
#  73: [['snowon_vh', 'tri', 'snowoff_cr', 'aspect', 'swir1'],
#   0.0010361574613853008],
#  74: [['green', 'swir1', 'red', 'curvature', 'snowon_vh'],
#   0.0008108919855658314],
#  75: [['aspect', 'swir1', 'snowon_vh', 'tri', 'curvature'],
#   0.0010728335173553205],
#  76: [['blue', 'latitude', 'snowoff_cr', 'tri', 'slope'],
#   0.0007318176940316334],
#  77: [['fcf', 'snowoff_cr', 'dowy', 'slope', 'swir1'], 0.0011204371362509846],
#  78: [['latitude', 'fcf', 'red', 'ndvi', 'snowon_vh'], 0.0007109837242751382],
#  79: [['snowoff_cr', 'nir', 'snowon_vv', 'tri', 'blue'],
#   0.0008575764468332636],
#  80: [['ndsi', 'snowoff_cr', 'delta_cr', 'latitude', 'snowon_cr'],
#   0.0006910643228366098],
#  81: [['snowon_vh', 'swir1', 'red', 'snowoff_vh', 'delta_cr'],
#   0.0005506026982402545],
#  82: [['snowoff_cr', 'swir1', 'snowoff_vv', 'green', 'red'],
#   0.00080386449371872],
#  83: [['slope', 'snowon_vh', 'tri', 'blue', 'swir2'], 0.0006921240315023169],
#  84: [['swir1', 'nir', 'latitude', 'ndwi', 'curvature'],
#   0.0008261519014922669],
#  85: [['green', 'red', 'curvature', 'snowoff_cr', 'tpi'],
#   0.0009730111332828528],
#  86: [['snowon_cr', 'fcf', 'snowoff_cr', 'ndsi', 'ndwi'],
#   0.0007131311413104413],
#  87: [['snowon_vh', 'ndwi', 'nir', 'red', 'blue'], 0.0009483371286478359],
#  88: [['dowy', 'latitude', 'snowoff_vh', 'ndsi', 'swir2'],
#   0.0007351413141805097],
#  89: [['snowoff_vh', 'tpi', 'green', 'ndvi', 'ndwi'], 0.0010769945738502429],
#  90: [['aspect', 'curvature', 'green', 'snowoff_cr', 'tri'],
#   0.0006928642251295969],
#  91: [['snowon_cr', 'snowoff_vv', 'fcf', 'tpi', 'curvature'],
#   0.001656759915931616],
#  92: [['ndwi', 'tpi', 'elevation', 'fcf', 'ndsi'], 0.0007707297431807092],
#  93: [['blue', 'nir', 'snowon_cr', 'fcf', 'swir1'], 0.0006258384980810661],
#  94: [['red', 'snowon_cr', 'ndsi', 'dowy', 'snowoff_vv'],
#   0.0005567157018049329],
#  95: [['slope', 'blue', 'nir', 'snowoff_vh', 'aspect'], 0.0008069459427133552],
#  96: [['delta_cr', 'ndsi', 'snowoff_vh', 'fcf', 'aspect'],
#   0.0008472820572933415],
#  97: [['aspect', 'red', 'snowon_cr', 'curvature', 'green'],
#   0.000631758303825336],
#  98: [['dowy', 'delta_cr', 'swir1', 'snowon_cr', 'snowon_vh'],
#   0.0009554581774864346],
#  99: [['swir2', 'swir1', 'aspect', 'snowoff_cr', 'delta_cr'],
#   0.0008443635992989584],
#  100: [['curvature', 'aspect', 'tri', 'swir2', 'snowoff_vv'],
#   0.0019135462534904946],
#  101: [['blue', 'green', 'snowoff_vv', 'red', 'fcf'], 0.0008133549554258934],
#  102: [['snowon_vv', 'latitude', 'snowon_vh', 'snowoff_vv', 'tpi'],
#   0.0013407258193183225],
#  103: [['curvature', 'aspect', 'snowoff_vh', 'snowon_vv', 'latitude'],
#   0.0017801170815801015],
#  104: [['elevation', 'tpi', 'snowon_vv', 'snowoff_vh', 'green'],
#   0.0007103808914052934],
#  105: [['longitude', 'latitude', 'slope', 'snowoff_vv', 'snowon_vh'],
#   0.0017137777522293618],
#  106: [['blue', 'delta_cr', 'ndvi', 'snowoff_vh', 'green'],
#   0.0007645196728844894],
#  107: [['latitude', 'snowon_vv', 'snowoff_vh', 'delta_cr', 'nir'],
#   0.0008065838273978443],
#  108: [['red', 'swir1', 'swir2', 'ndwi', 'ndvi'], 0.000886742021975806],
#  109: [['fcf', 'snowoff_vv', 'snowon_vh', 'tri', 'swir2'],
#   0.0009588192415321828],
#  110: [['aspect', 'longitude', 'elevation', 'ndsi', 'swir2'],
#   0.0007628614901022956],
#  111: [['delta_cr', 'longitude', 'ndvi', 'nir', 'curvature'],
#   0.0006695716801914386],
#  112: [['longitude', 'tri', 'snowon_cr', 'fcf', 'latitude'],
#   0.0016419939765910385],
#  113: [['snowoff_cr', 'curvature', 'snowon_vh', 'nir', 'red'],
#   0.0009987566395466274],
#  114: [['swir1', 'blue', 'delta_cr', 'red', 'curvature'],
#   0.0009476134232500044],
#  115: [['red', 'elevation', 'snowon_vv', 'longitude', 'snowon_vh'],
#   0.0006148204627152154],
#  116: [['snowoff_vh', 'latitude', 'curvature', 'swir1', 'tri'],
#   0.0014324879166451865],
#  117: [['delta_cr', 'snowon_vh', 'red', 'ndwi', 'swir1'],
#   0.0007522737523686374],
#  118: [['snowon_vh', 'snowoff_vv', 'swir2', 'blue', 'tpi'],
#   0.0005949402052465302],
#  119: [['dowy', 'snowon_vh', 'swir1', 'snowoff_vh', 'snowon_cr'],
#   0.0013669469917658716],
#  120: [['snowoff_vv', 'fcf', 'snowon_cr', 'snowon_vv', 'delta_cr'],
#   0.001028892700560391],
#  121: [['curvature', 'tpi', 'elevation', 'ndsi', 'snowoff_vv'],
#   0.001016963570691587],
#  122: [['delta_cr', 'swir2', 'red', 'ndwi', 'tpi'], 0.0008989650041257846],
#  123: [['ndwi', 'nir', 'snowon_vv', 'tpi', 'snowon_cr'], 0.000809305090115231],
#  124: [['ndwi', 'green', 'snowon_vh', 'curvature', 'ndvi'],
#   0.0006719153711856052],
#  125: [['fcf', 'green', 'slope', 'dowy', 'aspect'], 0.0007781934059494233],
#  126: [['delta_cr', 'snowon_vv', 'aspect', 'ndsi', 'curvature'],
#   0.0010208849744230974],
#  127: [['curvature', 'snowoff_cr', 'green', 'nir', 'tri'],
#   0.000571790451886045],
#  128: [['snowoff_cr', 'swir1', 'tri', 'green', 'snowoff_vh'],
#   0.0008159752128449327],
#  129: [['curvature', 'elevation', 'tpi', 'tri', 'swir1'],
#   0.0014229090857043047],
#  130: [['swir2', 'red', 'tpi', 'nir', 'snowon_vh'], 0.0008683095634296478],
#  131: [['snowon_vh', 'longitude', 'blue', 'snowoff_vv', 'snowoff_vh'],
#   0.0007179353551691747],
#  132: [['snowoff_vh', 'curvature', 'dowy', 'fcf', 'tpi'],
#   0.002014171790506225],
#  133: [['ndsi', 'snowon_cr', 'nir', 'delta_cr', 'aspect'],
#   0.0007369614645540423],
#  134: [['tri', 'green', 'swir1', 'snowon_vv', 'snowon_cr'],
#   0.00047577365626239043],
#  135: [['snowon_vv', 'fcf', 'latitude', 'ndwi', 'aspect'],
#   0.0011755504847315024],
#  136: [['snowon_vv', 'delta_cr', 'curvature', 'longitude', 'red'],
#   0.000766211693189689],
#  137: [['dowy', 'ndvi', 'slope', 'red', 'latitude'], 0.0007965282918576122],
#  138: [['snowoff_cr', 'nir', 'snowoff_vv', 'slope', 'swir2'],
#   0.0006635586942138616],
#  139: [['snowon_vv', 'snowoff_vh', 'latitude', 'nir', 'snowoff_vv'],
#   0.0007414764213535818],
#  140: [['delta_cr', 'swir2', 'elevation', 'red', 'snowoff_cr'],
#   0.0007440188428518013],
#  141: [['dowy', 'snowoff_vv', 'ndvi', 'snowoff_vh', 'blue'],
#   0.0010055144111902337],
#  142: [['delta_cr', 'tpi', 'blue', 'tri', 'ndvi'], 0.0008293119658446813],
#  143: [['snowon_vh', 'dowy', 'swir2', 'delta_cr', 'ndsi'],
#   0.0007639759469384444],
#  144: [['aspect', 'snowoff_vv', 'green', 'latitude', 'snowon_cr'],
#   0.0006982509858062258],
#  145: [['tpi', 'snowon_vv', 'elevation', 'swir1', 'dowy'],
#   0.000985269165084901],
#  146: [['ndsi', 'blue', 'delta_cr', 'tri', 'ndvi'], 0.0005378228233894333],
#  147: [['nir', 'latitude', 'tri', 'green', 'slope'], 0.0008351575820597645],
#  148: [['latitude', 'swir2', 'fcf', 'delta_cr', 'snowon_vh'],
#   0.001025598078740586],
#  149: [['slope', 'snowoff_vv', 'snowoff_cr', 'snowon_vv', 'green'],
#   0.0005797282110506785],
#  150: [['slope', 'snowon_vh', 'snowon_vv', 'latitude', 'delta_cr'],
#   0.0011329909739288269]}
